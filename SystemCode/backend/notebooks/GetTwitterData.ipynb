# %% [markdown]
# # Web scraper for Twitter Data

# %% [markdown]
# ## Install dependencies

# %%
! git clone https://github.com/eleow/Twitter-Get-Old-Tweets-Scraper
! pip install pyquery
# Out:
# Cloning into 'Twitter-Get-Old-Tweets-Scraper'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 86 (delta 0), reused 2 (delta 0), pack-reused 80
# Unpacking objects: 100% (86/86), done.

# %%
import os
os.chdir('/content/Twitter-Get-Old-Tweets-Scraper/old_tweets_crawler')
# os.getcwd()

from IPython.display import Audio, display
def done():
  display(Audio(url="https://www.pacdv.com/sounds/miscellaneous_sounds/magic-wand-1.wav", autoplay=True))

# %% [markdown]
# ## Set variables and run

# %%
from datetime import datetime
postfix=datetime.today().strftime("%Y_%m_%d_%H%M%S")

#@title Input Variables
num_tweets=100000 #@param {type:"slider", min:0, max:100000, step:100}
username="LiveSquawk" #@param ["CNBC", "LiveSquawk", "RANSquawk", "benzinga"] {allow-input:true}
since="2010-01-01" #@param {type:"date"}
to="2015-06-01" #@param {type:"date"}

output="tweets_"+username+"_"+postfix+".csv"

# %%
# !python main.py --username $username --max-tweets $num_tweets --query "" --output-file $output --since $since --until $to
done()
# Out:
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# 100 tweets added to file
# ERROR:main.py:expected string or bytes-like object
# Traceback (most recent call last):
#   File "main.py", line 18, in run
#     results = miner.get_tweets(tweet_criteria, buffer=exporter.output_to_file, verbose=verbose)
#   File "/content/Twitter-Get-Old-Tweets-Scraper/old_tweets_crawler/scraper/controllers.py", line 128, in get_tweets
#     text = re.sub('http', ' http', _('p.js-tweet-text').html())  # add spacing before an URL
#   File "/usr/lib/python3.6/re.py", line 191, in sub
#     return _compile(pattern, flags).sub(repl, string, count)
# TypeError: expected string or bytes-like object
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="https://www.pacdv.com/sounds/miscellaneous_sounds/magic-wand-1.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Download File from Google Colab

# %%
from google.colab import files
files.download(output)
